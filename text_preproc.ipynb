# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# ...
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/14.2 MB 5.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.6/14.2 MB 5.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.6/14.2 MB 5.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.6/14.2 MB 5.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.6/14.2 MB 5.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.6/14.2 MB 5.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.6/14.2 MB 5.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.6/14.2 MB 5.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.6/14.2 MB 5.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.6/14.2 MB 5.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.6/14.2 MB 5.2 MB/s eta 0:00:03
# ...

# %%
import re
import pandas as pd
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
spacy.__version__
# Out:
# '3.8.14'
